# %% [markdown]
# # Data Exploration
# # *Brands*

# %% [markdown]
# ## 0. Notes

# %% [markdown]
# **Note:**
# * short contains 3 character or digits
# * short and long have same length
# * long ones have duplicats
#
# **To Do:**
# * find the long brand names that have duplicated ✅

# %% [markdown]
# ## 1. Import csv File

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.close("all")

# %%
url = "https://drive.google.com/file/d/1m1ThDDIYRTTii-rqM5SEQjJ8McidJskD/view?usp=share_link" # brands.csv
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
brands_df = pd.read_csv(path)

# %% [markdown]
# ## 2. create Copy

# %%
brands = brands_df.copy()

# %% [markdown]
# ## 3. DataFrame dimensions

# %%
brands.shape

# %% [markdown]
# ## 4. DataFrame exploration

# %%
brands.head()

# %%
brands.tail()

# %%
brands.info()

# %%
brands.describe()

# %%
brands.nunique()

# %%
brands.isna().sum()

# %%
brands.duplicated().sum()

# %% [markdown]
# ## 5. Select Columns

# %% [markdown]
# ## 6. Select Rows

# %% [markdown]
# ## 7. Drop Columns

# %% [markdown]
# ## 8. Filter rows based on conditions

# %% [markdown]
# ## 9. Display Histogram

# %% [markdown]
# # Calculations

# %%
# find brands with duplicats
brands_dupl = brands.loc[brands["long"].duplicated() == True, ["long"]]
brands_dupl
brands[brands["long"] == "Apple"]
brands[brands["long"] == "Bose"]
brands[brands["long"] == "Jaybird"]
brands[brands["long"] == "Unknown"]
brands[brands["long"] == "Mophie"]
brands[brands["long"] == "Startech"]
# Out:
#     short      long
# 117   OTR  Startech
# 153   STA  Startech
