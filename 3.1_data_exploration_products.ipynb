# %% [markdown]
# # Data Exploration
# # *Products*

# %% [markdown]
# ## 0. Notes

# %% [markdown]
# **Note:**
#
# * products contains a lot of duplicats -> drop_duplicates ✅
#
# * price is an object should be float
# * promo_price is object should be float
# * prices and promo_prices are weird xx.xxx.xxx
# *
# * price contains NaN
# * in_stock contains NaN
# * desc and price and type have NaN value
#
# **Info**
# * sku has suffices
# * products sku: 10579 vs orderline sku: 7951
# * promo_price and price vastly different
# * type 4-digit numbers but some have more, some duplicats

# %% [markdown]
# ## 1. Import csv File

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.close("all")

# %%
url = "https://drive.google.com/file/d/1afxwDXfl-7cQ_qLwyDitfcCx3u7WMvkU/view?usp=share_link" # products.csv
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_df = pd.read_csv(path)

# %% [markdown]
# ## 2. create Copy

# %%
products = products_df.copy()

# %% [markdown]
# ## 3. DataFrame dimensions

# %%
products.shape
# Out:
# (19326, 7)

# %% [markdown]
# ## 4. DataFrame exploration

# %%
products.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %%
products.tail()

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10580 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10580 non-null  object
#  1   name         10580 non-null  object
#  2   desc         10573 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10580 non-null  object
#  5   in_stock     10580 non-null  int64
#  6   type         10530 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 661.2+ KB

# %%
products.describe()

# %%
products.nunique()
# Out:
# sku            10579
# name           10373
# desc            7098
# price           2690
# promo_price     4614
# in_stock           2
# type             126
# dtype: int64

# %%
#check
products["price"].unique() 
products["promo_price"].unique()
# Out:
# array(['499.899', '589.996', '569.898', ..., '4.265.843', '440.004',
#        '1.499.795'], dtype=object)

# %%
products.isna().sum()

# %%
#check
#products[products["price"].isna()]
#products.loc[products["type"].isna(),]
#products[products["desc"].isna()]

# products.loc[products["type"].isna(),].sort_values(by="sku")

# %%
products.duplicated().sum()

# %%
products.nlargest(5, "in_stock")

# %%
products.nsmallest(5, "in_stock")

# %% [markdown]
# ## 5. Select Columns

# %% [markdown]
# ## 6. Select Rows

# %% [markdown]
# ## 7. Drop Columns

# %%
# drop the duplicate columns 
products = products.drop_duplicates()
len(products)

# %% [markdown]
# ## 8. Filter rows based on conditions

# %% [markdown]
# ## 9. Change Data Type

# %%
products["price"].unique()

# %%
# change price
products["price"].str.contains("")

# %%
# check why prices are object - potentially , vs .

products["price"].str.contains("\d\,\d", regex = True).sum()
products["promo_price"].str.contains("\d\.\d", regex = True).sum()
# Out:
# 10455

# %%
# change promo_price

# %% [markdown]
# ## 9. Display Histogram

# %% [markdown]
# **Note:**
# * < 2500 articles are in_stock

# %%
# hist: how many products are in_stock
products["in_stock"].hist()

# %%
# plot type and stock
products.groupby("type").sum("in_stock").plot()

# %% [markdown]
# certain types are in stock much more

# %% [markdown]
# # Calculations

# %%
products
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %%
# amount of products in list
len(products)

# %%
# amount of unique products 
products["sku"].nunique()
# Out:
# 10579

# %%
# number of unique different types
products["type"].nunique()

# %%
# unique names of different types 
products["type"].unique()

# %%
# how many products are in_stock, where value = 1
products["in_stock"].sum()

# %%
# calc: % of in_stock products 
products["in_stock"].sum()/products["sku"].count()

# %%
# max amount of products in_stock?
max_num = products.groupby("type").sum("in_stock").max()

# %%
# which type has max amount ?
#products[products.groupby("type").sum("in_stock") == max_num]["type"]

## not working

# %%
# min amount of articles in stock 
min_num = products.groupby("type").sum("in_stock").min()
# Out:
# in_stock    0
# dtype: int64

# %%
# which type has min amount ?
#products[products.groupby("type").sum("in_stock") == min_num]["type"]

## not working
